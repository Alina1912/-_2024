# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import os

# Создаем список для хранения данных из всех файлов
data_list = []

# Чтение данных из каждого файла в папке simpsons_fixations
for file in os.listdir('Simpsons_fixations'):
    if file.endswith('.csv'):
        df = pd.read_csv(os.path.join('Simpsons_fixations', file))
        data_list.append(df)

# Построение графиков для каждого файла
# for df in data_list:
#     plt.figure()
#     for index, row in df.iterrows():
#         color = 'red' if row['duration [ms]'] < 1000 else 'blue'
#         plt.scatter(row['fixation x [px]'], row['fixation y [px]'], c=color)
#         plt.text(row['fixation x [px]'], row['fixation y [px]'], str(row['fixation id']))
#     plt.xlabel('Fixation x [px]')
#     plt.ylabel('Fixation y [px]')
#     plt.title('Fixations')
#     plt.show()

# %%
# Кластеризация данных с помощью KMeans
for df in data_list:
    kmeans = KMeans(n_clusters=2)  # Укажите количество кластеров
    kmeans.fit(df[['fixation x [px]', 'fixation y [px]']])
    df['cluster'] = kmeans.labels_

# Вывод результата кластеризации
print(df)
# Out:
# /home/alinashishcova/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/alinashishcova/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/alinashishcova/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/alinashishcova/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# ...

# %%
for df in data_list:
    kmeans = KMeans(n_clusters=2)  # Укажите количество кластеров
    X = kmeans.fit(df[['fixation x [px]', 'fixation y [px]']])
    for i in range(kmeans.n_clusters):
        cluster_points = X[kmeans.labels_ == i]
        mean = np.mean(cluster_points, axis=0)
    df['cluster'] = kmeans.labels_
    plt.figure()
    for index, row in df.iterrows():
        color = 'red' if row['cluster'] == 0 else 'blue'
        plt.scatter(row['fixation x [px]'], row['fixation y [px]'], c=color)
        plt.text(row['fixation x [px]'], row['fixation y [px]'], str(row['fixation id']))
    plt.xlabel('Fixation x [px]')
    plt.ylabel('Fixation y [px]')
    plt.title('Fixations')
    plt.show()
# Out:
# /home/alinashishcova/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [16], line 5
#       3 X = kmeans.fit(df[['fixation x [px]', 'fixation y [px]']])
#       4 for i in range(kmeans.n_clusters):
# ----> 5     cluster_points = X[kmeans.labels_ == i]
#       6     mean = np.mean(cluster_points, axis=0)
#       7 df['cluster'] = kmeans.labels_
#
# TypeError: 'KMeans' object is not subscriptable

# %%
for i in range(kmeans.n_clusters):
    cluster_points = X[labels == i]
    mean = np.mean(cluster_points, axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 2
#       1 for i in range(kmeans.n_clusters):
# ----> 2     cluster_points = X[labels == i]
#       3     mean = np.mean(cluster_points, axis=0)
#
# NameError: name 'labels' is not defined

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# Читаем все файлы в список датафреймов
# file_names = ['file1.csv', 'file2.csv', ..., 'file17.csv']
# dfs = [pd.read_csv(file_name) for file_name in file_names]

# Выполняем к-меанс кластеризацию для каждого датафрейма
for df in data_list:
    kmeans = KMeans(n_clusters=2, random_state=0)
    kmeans.fit(df[['fixation y [px]']])  # Кластеризуем только по оси y
    df['cluster'] = kmeans.labels_
    proportion = (df['cluster'] == 1).sum() / len(df)
    # Проверяем, какой кластер содержит точки с большей координатой по оси y
    if df[df['cluster'] == 1]['fixation y [px]'].mean() > df[df['cluster'] == 0]['fixation y [px]'].mean():
        df['cluster'] = df['cluster'].apply(lambda x: 1 - x)
    plt.figure()
    for index, row in df.iterrows():
        color = 'red' if row['cluster'] == 0 else 'blue'
        plt.scatter(row['fixation x [px]'], row['fixation y [px]'], c=color)
        plt.text(row['fixation x [px]'], row['fixation y [px]'], str(row['fixation id']))
    plt.xlabel('Fixation x [px]')
    plt.ylabel('Fixation y [px]')
    plt.title('Fixations')
    plt.show()
    print(proportion)
# Объединяем все датафреймы в один
# result = pd.concat(dfs)
# Out:
# /home/alinashishcova/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 0.4931237721021611
# /home/alinashishcova/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 0.49493243243243246
# /home/alinashishcova/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 0.26
# ...

# %%
data_list = []

# Чтение данных из каждого файла в папке simpsons_fixations
for file in os.listdir('spongebob_fixations'):
    if file.endswith('.csv'):
        df = pd.read_csv(os.path.join('spongebob_fixations', file))
        data_list.append(df)
for df in data_list:
    kmeans = KMeans(n_clusters=2, random_state=0)
    kmeans.fit(df[['fixation y [px]']])  # Кластеризуем только по оси y
    df['cluster'] = kmeans.labels_
    proportion = (df['cluster'] == 1).sum() / len(df)
    print(proportion)
# Out:
# 0.4938488576449912
# 0.4015151515151515
# 0.41533546325878595
# 0.7348148148148148
# 0.38671875
# 0.36231884057971014
# 0.6039279869067103
# 0.6654970760233918
# 0.5217391304347826
# 0.5379310344827586
# 0.5475409836065573
# 0.4450354609929078
# 0.3932748538011696
# 0.29638854296388545
# 0.5195729537366548
# 0.6214953271028038
# 0.4227353463587922
